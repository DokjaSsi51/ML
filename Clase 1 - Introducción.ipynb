# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
datos = Series(['juan','Pedro','Luis'])
datos
# Out:
# 0     juan
# 1    Pedro
# 2     Luis
# dtype: object

# %%
datos1 = Series(['Juan','Pedro','Luis'],index =['a','b','c'])
datos1
# Out:
# a     Juan
# b    Pedro
# c     Luis
# dtype: object

# %%
datos1.values
# Out:
# array(['Juan', 'Pedro', 'Luis'], dtype=object)

# %%
datos1['a']
# Out:
# 'Juan'

# %%
datos[0]
# Out:
# 'juan'

# %%
datos1['d'] = 'mapiripan'
datos1
# Out:
# a         Juan
# b        Pedro
# c         Luis
# d    mapiripan
# dtype: object

# %%
sdata = {'Pedro':23,
         'Juan':31,
         'Maria':18}

# %%
data = Series(sdata)
data
# Out:
# Pedro    23
# Juan     31
# Maria    18
# dtype: int64

# %%
data.index
# Out:
# Index(['Pedro', 'Juan', 'Maria'], dtype='object')

# %%
data.values
# Out:
# array([23, 31, 18])

# %%
dicc = {'Departamento':['Atlántico','Bolívar','Sucre'],
        'Año':[2000,2010,2005],
        'Población':[1.5,3.0,1.0]}
dicc
# Out:
# {'Departamento': ['Atlántico', 'Bolívar', 'Sucre'],
#  'Año': [2000, 2010, 2005],
#  'Población': [1.5, 3.0, 1.0]}

# %%
df = DataFrame(dicc)
df
# Out:
#   Departamento   Año  Población
# 0    Atlántico  2000        1.5
# 1      Bolívar  2010        3.0
# 2        Sucre  2005        1.0

# %%
df1 = DataFrame(dicc,columns = ['Año','Población','Departamento'])
df1
# Out:
#     Año  Población Departamento
# 0  2000        1.5    Atlántico
# 1  2010        3.0      Bolívar
# 2  2005        1.0        Sucre

# %%
df1 = DataFrame(dicc,columns = ['Año','Población','Departamento','Area'])
df1
# Out:
#     Año  Población Departamento Area
# 0  2000        1.5    Atlántico  NaN
# 1  2010        3.0      Bolívar  NaN
# 2  2005        1.0        Sucre  NaN

# %%
df1['Area'] = [1200,3000,2000]
df1
# Out:
#     Año  Población Departamento  Area
# 0  2000        1.5    Atlántico  1200
# 1  2010        3.0      Bolívar  3000
# 2  2005        1.0        Sucre  2000

# %%
del df1['Area']
df1
# Out:
#     Año  Población Departamento
# 0  2000        1.5    Atlántico
# 1  2010        3.0      Bolívar
# 2  2005        1.0        Sucre

# %% [markdown]
# ### Leer dataset csv ###

# %%
data = pd.read_csv('Datasets/titanic/titanic3.csv')

# %%
data.head(6)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data.iloc[10]
# Out:
# pclass                            1
# survived                          0
# name         Astor, Col. John Jacob
# sex                            male
# age                            47.0
# sibsp                             1
# parch                             0
# ticket                     PC 17757
# fare                        227.525
# cabin                       C62 C64
# embarked                          C
# boat                            NaN
# body                          124.0
# home.dest              New York, NY
# Name: 10, dtype: object

# %%
data.iloc[10:15]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
#
#        sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# 10    male  47.0      1      0  PC 17757  227.525  C62 C64        C  NaN
# 11  female  18.0      1      0  PC 17757  227.525  C62 C64        C    4
# 12  female  24.0      0      0  PC 17477   69.300      B35        C    9
# 13  female  26.0      0      0     19877   78.850      NaN        S    6
# 14    male  80.0      0      0     27042   30.000      A23        S    B
#
#      body      home.dest
# 10  124.0   New York, NY
# 11    NaN   New York, NY
# ...

# %%
data.shape
# Out:
# (1309, 14)

# %% [markdown]
# ### Formato Excel ###

# %%
data = pd.read_excel('Datasets/titanic/titanic3.xls','titanic3')
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df = df.to_csv('Datasets/df.csv')

# %% [markdown]
# ### Análisis preliminar ###

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000
