# %% [markdown]
# ## Regresión de Ridgen ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Datasets/Customer Churn Model.txt')
data.head(2)
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3          2.7
# 1       254.4          103         11.45       13.7           3          3.7
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
#
# [2 rows x 21 columns]

# %%
x = ['Night Mins','Night Calls']
x = np.array(data[x])
y = ['Night Charge']
y = np.array(data[y])

# %%
#Escalador
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)
y = scaler.fit_transform(y)

# %%
print(x)
# Out:
# [[ 0.86674322 -0.46549436]
#  [ 1.05857074  0.14782467]
#  [-0.75686906  0.19893459]
#  ...
#  [-0.1774313  -0.46549436]
#  [-1.21962822  1.88556193]
#  [ 0.80148231 -1.18103324]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge(alpha = 0.1)

# %%
ridge.alpha
# Out:
# 0.1

# %%
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
ridge.intercept_, ridge.coef_
# Out:
# (array([9.29699214e-06]), array([ 9.99966098e-01, -3.18768479e-05]))

# %%
y_pred = ridge.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9999983704944747

# %% [markdown]
# ## Regresión de Lasso ##

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso(alpha = 0.1)

# %%
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso.intercept_, lasso.coef_
# Out:
# (array([-0.0004349]), array([0.90038567, 0.        ]))

# %%
y_pred_l = lasso.predict(x_test)

# %%
r2_score(y_test,y_pred_l)
# Out:
# 0.9900732530817675

# %%
from Fisica.modelo_lineal import Ridge
from Fisica.modelo_lineal import Lasso

# %%
rid = Ridge()
las = Lasso()

# %%
rid.fit(x_train,y_train)
las.fit(x_train,y_train)

# %%
rid.intercept, rid.coef
# Out:
# (array([9.2966434e-06]),
#  array([[ 9.99966098e-01],
#         [-3.18768512e-05]]))

# %%
las.intercept, las.coef
# Out:
# (array([-2.37485363]),
#  array([[529.60867002],
#         [  0.        ]]))

# %%
y_pred_r = rid.predict(x_test)
y_pred_l = las.predict(x_test)

# %%
r2_score(y_test,y_pred_r)
# Out:
# 0.9999983704945071

# %%
r2_score(y_pred,y_pred_l)
# Out:
# -279495.40343180025
